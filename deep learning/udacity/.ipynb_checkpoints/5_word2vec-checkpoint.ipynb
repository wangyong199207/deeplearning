# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
       'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'anarchism', 'a', 'originated', 'of', 'term', 'as']

# %%
valid_examples.shape
# Out:
# (16,)

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.119181
# Nearest to however: health, lovers, theirs, usury, subscriptions, installer, bonanza, manichaean,
# Nearest to no: cutler, biologically, isolated, torino, getter, translocation, aragonese, murdered,
# Nearest to d: utilitarian, budgeted, sufferer, vit, originator, xxv, dillon, economic,
# Nearest to during: cholas, probe, excavations, thucydides, inefficiencies, caters, limousine, notion,
# Nearest to this: eusebius, approval, horribilis, reiterated, provenance, glenda, posen, perceval,
# Nearest to seven: vehicle, lever, payload, classifications, mobilization, settlement, fhm, trilingual,
# Nearest to been: proposals, belarus, pelagic, augustinians, marijuana, wilhelmshaven, ababa, mather,
# Nearest to it: md, disable, torsion, koizumi, mescaline, solar, schaeffer, sincere,
# Nearest to may: dante, jill, sabina, mannerheim, implicated, sphere, comedienne, maitland,
# Nearest to was: gillette, pergamon, dara, neuropathy, abel, blotting, affections, albigensian,
# Nearest to history: pediment, sailing, not, restrain, pragmatic, genocides, mammoths, angelica,
# Nearest to world: culminated, machiavelli, stalemate, fanfic, eduard, commissioners, endeavours, contributing,
# Nearest to would: sculptors, anesthesia, gran, wondering, salvadoran, ekspres, malvaceae, dojos,
# Nearest to are: thousandth, kneel, headstone, semitone, wealthier, arcologies, intersections, community,
# Nearest to also: chalcedonian, sancho, chariot, calif, fibrosis, independence, dfs, frites,
# Nearest to three: tradeoff, convicted, finance, disposable, unknowns, contrary, include, kareem,
# Average loss at step 2000: 4.360770
# Average loss at step 4000: 3.857529
# Average loss at step 6000: 3.786051
# Average loss at step 8000: 3.679609
# Average loss at step 10000: 3.613984
# Nearest to however: but, lovers, repeating, condenser, although, technische, hlich, health,
# Nearest to no: almost, rensselaer, rosser, hydrocarbons, frequently, it, barnum, maryland,
# Nearest to d: xxv, utilitarian, scandal, heinlein, ssn, sufferer, violently, dash,
# Nearest to during: thucydides, in, excavations, after, nobody, cholas, minurso, birth,
# Nearest to this: it, the, which, multihull, that, a, tammy, venereal,
# Nearest to seven: six, eight, three, five, nine, four, zero, two,
# Nearest to been: seizure, ibadi, hasbro, chydenius, ectopic, often, randy, seagram,
# Nearest to it: he, there, this, they, she, staples, not, which,
# Nearest to may: might, would, can, will, must, jill, tley, feinstein,
# Nearest to was: is, has, had, were, by, ottoman, kohlberg, neuropathy,
# Nearest to history: sailing, contemporaneously, grooming, official, pediment, judaism, basalt, bolivar,
# Nearest to world: earth, culminated, tolerable, moorehead, machiavelli, catapults, superb, fanfic,
# Nearest to would: can, may, will, could, might, consonances, tanker, does,
# Nearest to are: were, is, have, but, do, reith, advocated, be,
# Nearest to also: fibrosis, which, now, it, often, ballets, reductionism, game,
# Nearest to three: eight, seven, four, five, six, nine, two, zero,
# Average loss at step 12000: 3.603443
# Average loss at step 14000: 3.573113
# Average loss at step 16000: 3.406716
# Average loss at step 18000: 3.458309
# Average loss at step 20000: 3.539579
# Nearest to however: but, although, since, though, condenser, repeating, cladogram, socially,
# Nearest to no: hydrocarbons, any, rensselaer, almost, anatoly, serena, a, translocation,
# Nearest to d: b, xxv, ssn, joanne, utilitarian, dash, immanence, deception,
# Nearest to during: in, after, thucydides, before, matte, nobody, from, soulful,
# Nearest to this: it, which, the, that, tammy, working, condemn, convents,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to been: seizure, never, be, already, was, ibadi, chydenius, become,
# Nearest to it: he, this, there, she, they, which, centimeter, not,
# Nearest to may: can, would, might, will, must, could, crater, tley,
# Nearest to was: is, has, were, had, be, kohlberg, became, are,
# Nearest to history: sailing, basalt, official, grooming, chromosome, bolivar, contemporaneously, pragmatic,
# Nearest to world: earth, tolerable, culminated, moorehead, quote, catapults, superb, congo,
# Nearest to would: will, can, may, could, might, must, should, does,
# Nearest to are: were, is, have, was, although, existing, do, hlich,
# Nearest to also: which, now, often, usually, not, fibrosis, finer, lamorna,
# Nearest to three: four, five, two, seven, six, eight, nine, one,
# Average loss at step 22000: 3.504924
# Average loss at step 24000: 3.490264
# Average loss at step 26000: 3.483632
# Average loss at step 28000: 3.484159
# Average loss at step 30000: 3.503463
# Nearest to however: but, although, though, since, condenser, gloster, cap, probably,
# Nearest to no: rensselaer, any, a, hydrocarbons, it, harem, anatoly, steadfastly,
# Nearest to d: b, xxv, joanne, ssn, utilitarian, immanence, sanders, heinlein,
# Nearest to during: after, before, in, until, from, on, under, when,
# Nearest to this: which, it, that, any, glassy, some, convents, the,
# Nearest to seven: five, eight, nine, four, six, three, zero, two,
# Nearest to been: was, already, become, were, be, seizure, never, chydenius,
# Nearest to it: he, she, this, there, they, still, which, not,
# Nearest to may: can, would, will, could, might, must, should, crater,
# Nearest to was: is, were, had, has, been, became, being, when,
# Nearest to history: basalt, sailing, official, pragmatic, chromosome, northwestern, estado, grooming,
# Nearest to world: earth, tolerable, culminated, quote, moorehead, seawater, catapults, announces,
# Nearest to would: will, can, may, could, might, should, must, does,
# Nearest to are: were, is, have, these, do, spoilage, although, annunciation,
# Nearest to also: often, now, which, sometimes, nicks, usually, actually, never,
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Average loss at step 32000: 3.501781
# Average loss at step 34000: 3.492849
# Average loss at step 36000: 3.449547
# Average loss at step 38000: 3.303417
# Average loss at step 40000: 3.431558
# Nearest to however: but, although, though, that, masse, it, while, gloster,
# Nearest to no: any, rensselaer, hydrocarbons, there, typically, wyclif, anatoly, responds,
# Nearest to d: b, sanders, sufferer, xxv, e, temperament, utilitarian, ben,
# Nearest to during: after, until, before, in, from, when, throughout, thucydides,
# Nearest to this: which, it, the, another, grafton, any, colonialism, that,
# Nearest to seven: five, eight, six, nine, four, zero, three, two,
# Nearest to been: become, be, already, was, never, were, seizure, gah,
# Nearest to it: he, she, there, they, this, still, which, often,
# Nearest to may: can, would, could, will, might, must, should, cannot,
# Nearest to was: is, has, had, became, were, did, been, be,
# Nearest to history: pragmatic, sailing, northwestern, grooming, official, belligerent, chromosome, basalt,
# Nearest to world: earth, tolerable, quote, pad, superb, aquarium, culminated, moorehead,
# Nearest to would: will, could, can, may, should, might, must, does,
# Nearest to are: were, have, although, while, include, reith, is, these,
# Nearest to also: now, often, usually, which, sometimes, nicks, never, it,
# Nearest to three: two, four, five, seven, six, eight, nine, zero,
# Average loss at step 42000: 3.433369
# Average loss at step 44000: 3.454922
# Average loss at step 46000: 3.447813
# Average loss at step 48000: 3.347261
# Average loss at step 50000: 3.383839
# Nearest to however: but, although, though, that, while, and, when, where,
# Nearest to no: any, a, rensselaer, typically, candle, applesoft, little, wyclif,
# Nearest to d: b, sufferer, xxv, e, sketches, sanders, ben, ssn,
# Nearest to during: after, in, throughout, until, before, through, from, although,
# Nearest to this: which, it, the, autographs, he, grafton, some, that,
# Nearest to seven: eight, six, nine, four, three, five, zero, two,
# Nearest to been: become, already, be, chydenius, gah, was, were, seizure,
# Nearest to it: he, she, there, this, still, they, now, often,
# Nearest to may: can, would, will, could, must, might, should, cannot,
# Nearest to was: is, has, were, had, became, be, being, by,
# Nearest to history: pragmatic, placement, sailing, basalt, chromosome, entire, list, recipient,
# Nearest to world: earth, tolerable, quote, superb, pad, seawater, raping, congreso,
# Nearest to would: will, could, can, may, should, might, must, does,
# Nearest to are: were, is, have, do, these, helped, include, those,
# Nearest to also: now, often, which, usually, actually, sometimes, still, below,
# Nearest to three: six, seven, four, eight, two, nine, five, zero,
# Average loss at step 52000: 3.433649
# Average loss at step 54000: 3.425844
# Average loss at step 56000: 3.438630
# Average loss at step 58000: 3.398625
# Average loss at step 60000: 3.388832
# Nearest to however: but, although, though, that, asuras, when, during, since,
# Nearest to no: any, little, typically, rensselaer, chronologically, a, landscapes, exiling,
# Nearest to d: b, sanders, sketches, joanne, e, sufferer, y, ssn,
# Nearest to during: after, before, throughout, in, until, although, within, through,
# Nearest to this: which, it, that, there, what, the, facet, anheuser,
# Nearest to seven: eight, nine, four, six, five, three, zero, one,
# Nearest to been: become, be, gah, already, had, chydenius, was, were,
# Nearest to it: he, there, this, she, still, they, now, what,
# Nearest to may: can, would, could, will, might, must, should, cannot,
# Nearest to was: is, had, became, has, were, did, be, when,
# Nearest to history: placement, journal, philosophy, list, pragmatic, elephants, subcommittee, basalt,
# Nearest to world: tolerable, earth, seawater, economy, quote, congreso, bcl, announces,
# Nearest to would: could, will, may, can, should, must, might, does,
# Nearest to are: were, is, have, be, although, these, include, including,
# Nearest to also: often, now, still, sometimes, actually, previously, which, below,
# Nearest to three: four, five, six, eight, two, seven, nine, zero,
# Average loss at step 62000: 3.246106
# Average loss at step 64000: 3.254028
# Average loss at step 66000: 3.401212
# Average loss at step 68000: 3.397620
# Average loss at step 70000: 3.361391
# Nearest to however: but, although, though, that, while, when, where, which,
# Nearest to no: any, little, typically, rensselaer, chronologically, adversaries, there, wyclif,
# Nearest to d: b, xxv, joanne, sketches, sufferer, sanders, temperament, y,
# Nearest to during: after, before, throughout, until, in, since, through, within,
# Nearest to this: which, it, that, itself, the, there, another, what,
# Nearest to seven: nine, eight, six, four, five, three, zero, two,
# Nearest to been: become, be, already, was, were, had, chydenius, gah,
# Nearest to it: he, she, there, this, they, still, now, usually,
# Nearest to may: can, could, will, would, must, might, should, cannot,
# Nearest to was: is, were, has, had, became, been, when, be,
# Nearest to history: journal, placement, list, philosophy, pragmatic, subcommittee, peruvian, underage,
# Nearest to world: tolerable, earth, seawater, cadiz, quote, botc, enclaves, bcl,
# Nearest to would: will, could, can, may, might, should, must, does,
# Nearest to are: were, have, include, is, these, including, while, although,
# Nearest to also: often, now, which, still, sometimes, previously, actually, phallic,
# Nearest to three: four, six, two, five, seven, zero, eight, nine,
# Average loss at step 72000: 3.370891
# Average loss at step 74000: 3.349530
# Average loss at step 76000: 3.307437
# Average loss at step 78000: 3.355834
# Average loss at step 80000: 3.374887
# Nearest to however: although, but, though, that, while, asuras, where, when,
# Nearest to no: little, any, adversaries, landscapes, basalt, typically, nayla, escarpment,
# Nearest to d: b, sanders, joanne, sketches, unchanged, temperament, ben, chromosphere,
# Nearest to during: after, in, before, throughout, until, although, despite, when,
# Nearest to this: which, it, the, itself, there, glassy, conspicuously, polymyositis,
# Nearest to seven: six, five, eight, four, nine, three, zero, one,
# Nearest to been: become, be, already, was, had, gah, chydenius, were,
# Nearest to it: he, she, there, this, they, still, weasel, actually,
# Nearest to may: can, could, will, would, must, might, should, cannot,
# Nearest to was: is, were, became, had, has, been, although, being,
# Nearest to history: journal, placement, philosophy, transpersonal, subcommittee, peruvian, pragmatic, list,
# Nearest to world: tolerable, seawater, bcl, quote, earth, botc, culminated, zhejiang,
# Nearest to would: will, could, can, may, should, might, must, did,
# Nearest to are: were, include, is, have, these, although, those, including,
# Nearest to also: now, often, which, still, previously, sometimes, actually, never,
# Nearest to three: six, five, four, eight, seven, two, nine, zero,
# Average loss at step 82000: 3.405864
# Average loss at step 84000: 3.414186
# Average loss at step 86000: 3.387007
# Average loss at step 88000: 3.353423
# Average loss at step 90000: 3.364365
# Nearest to however: but, although, though, that, since, asuras, while, proprietors,
# Nearest to no: little, any, only, basalt, escarpment, now, typically, adversaries,
# Nearest to d: b, sketches, friedrich, sanders, ben, hp, joanne, sufferer,
# Nearest to during: before, after, in, throughout, although, despite, through, until,
# Nearest to this: which, it, itself, the, some, convents, any, arsenate,
# Nearest to seven: eight, five, four, six, nine, three, zero, one,
# Nearest to been: become, be, already, was, being, suffered, gah, chydenius,
# Nearest to it: he, she, there, this, they, never, then, still,
# Nearest to may: can, could, must, should, will, might, would, cannot,
# Nearest to was: is, became, had, were, has, been, be, becomes,
# Nearest to history: list, journal, creation, spill, placement, version, philosophy, trumped,
# Nearest to world: seawater, earth, tolerable, culminated, bcl, quote, congressional, declension,
# Nearest to would: will, could, can, might, may, should, must, did,
# Nearest to are: were, is, these, include, although, have, while, annunciation,
# Nearest to also: often, now, still, which, actually, never, previously, sometimes,
# Nearest to three: five, four, two, eight, six, seven, nine, zero,
# Average loss at step 92000: 3.402098
# Average loss at step 94000: 3.251725
# Average loss at step 96000: 3.353722
# Average loss at step 98000: 3.242716
# Average loss at step 100000: 3.357006
# Nearest to however: but, although, though, that, especially, while, asuras, and,
# Nearest to no: little, any, only, adversaries, basalt, now, unruly, sarai,
# Nearest to d: b, r, joanne, xxv, sanders, heinlein, h, shan,
# Nearest to during: in, throughout, before, after, through, until, within, at,
# Nearest to this: which, it, itself, another, the, sail, some, grafton,
# Nearest to seven: eight, five, four, six, nine, three, zero, two,
# Nearest to been: become, be, already, was, gah, chydenius, recently, suffered,
# Nearest to it: he, she, this, there, they, never, which, forth,
# Nearest to may: can, could, should, must, might, would, will, cannot,
# Nearest to was: is, became, has, were, had, been, becomes, be,
# Nearest to history: list, spill, journal, placement, chromosome, entire, peruvian, creation,
# Nearest to world: seawater, tolerable, earth, country, declension, bcl, congreso, culminated,
# Nearest to would: could, will, might, may, can, should, must, did,
# Nearest to are: were, have, those, include, these, although, is, while,
# Nearest to also: still, now, never, actually, often, which, sometimes, previously,
# Nearest to three: five, four, two, eight, six, seven, nine, zero,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))  
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                               train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, bag_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.100234
# Nearest to on: berg, aetius, bering, airways, accomplices, oddly, gauguin, pga,
# Nearest to states: magdalen, withdraws, adware, esteemed, purchasers, druze, brainiac, astros,
# Nearest to they: confucius, discord, fail, connection, usurpers, fried, fulfilling, skylark,
# Nearest to as: uranus, survey, longer, midlands, thursdays, hinds, port, uz,
# Nearest to this: pulaski, proved, swell, wuppertal, saline, helm, deluge, mpaa,
# Nearest to see: hypercard, crystal, ozone, intended, pekka, stouffer, hourly, stellated,
# Nearest to only: doc, pennant, rocketry, turkestan, entries, antigen, placenta, radiohead,
# Nearest to some: discern, exemplifies, pretense, constipation, omits, idol, subnational, federalism,
# Nearest to all: guadalcanal, astonishing, technicalities, catv, desertion, mushroom, crying, gallup,
# Nearest to is: hfs, counties, enumerated, tr, samoan, arouse, dinneen, fini,
# Nearest to but: cyg, consultative, talented, prolonging, recommended, oc, stimulant, moriarty,
# Nearest to world: emphasize, knife, ilp, riverine, whodunit, edvac, harriet, documents,
# Nearest to his: ketones, temair, annihilated, cyborgs, polybius, indicators, alien, normality,
# Nearest to who: deflate, moron, wreckin, synoptic, mud, howe, cooperatively, lignite,
# Nearest to and: middlesex, bogdanovich, nationalities, platelets, monist, pickford, toxin, wainwright,
# Nearest to may: grapevine, cycles, kilmister, killing, unsympathetic, ascent, cells, halfbakery,
# Average loss at step 2000: 9.644560
# Average loss at step 4000: 6.115627
# Average loss at step 6000: 5.273768
# Average loss at step 8000: 4.693352
# Average loss at step 10000: 4.047241
# Nearest to on: in, ethnocentric, lindbergh, cleansed, swiftly, wonderswan, peasantry, npc,
# Nearest to states: kingdom, tran, rejoiced, gobind, zhejiang, gridiron, huntingdon, ventricle,
# Nearest to they: he, she, there, it, we, anglophones, notation, you,
# Nearest to as: macrae, disjoint, endeavors, outfitted, interacts, interpolated, clubs, langston,
# Nearest to this: it, the, vr, what, an, theirs, capacitors, christof,
# Nearest to see: syllabary, hurling, hypercard, irradiation, stellated, artists, upwelling, someday,
# Nearest to only: dimensionless, subarctic, dish, epsom, fluent, do, excretory, sportswriters,
# Nearest to some: many, several, most, the, predecessor, everyman, presupposition, demonstrating,
# Nearest to all: scarred, guadalcanal, those, kocher, many, jafar, these, club,
# Nearest to is: was, has, are, became, discord, rally, does, pondering,
# Nearest to but: undermine, fleury, and, although, ticketing, or, magie, assign,
# Nearest to world: idriss, shapiro, age, alsace, disorder, machine, duluth, amman,
# Nearest to his: their, her, its, oakley, the, freelance, parliamentarian, leda,
# Nearest to who: he, howe, drying, strength, testimony, she, verifies, multifinder,
# Nearest to and: or, but, jogging, grinder, arminius, breathing, malaise, longing,
# Nearest to may: can, should, pennsylvania, could, female, mason, improvisation, school,
# Average loss at step 12000: 4.257491
# Average loss at step 14000: 4.087136
# Average loss at step 16000: 4.069189
# Average loss at step 18000: 3.789034
# Average loss at step 20000: 3.407775
# Nearest to on: upon, tamer, hemoglobin, cleansed, in, ethnocentric, palermo, iic,
# Nearest to states: kingdom, nations, purcell, parables, driftwood, vaccinium, tran, ventricle,
# Nearest to they: we, he, there, you, these, mpv, it, amendments,
# Nearest to as: embezzlement, auction, restorations, fireside, sandro, lustrous, grady, qaddafi,
# Nearest to this: it, which, barton, that, a, defends, theirs, the,
# Nearest to see: jacksonville, delocalised, blimp, includes, lir, syllabary, vanish, superboy,
# Nearest to only: sbc, still, cx, workshop, acculturation, rhead, collapsing, maybe,
# Nearest to some: many, various, several, these, both, most, different, graduates,
# Nearest to all: many, various, some, cocaine, stellar, curls, formants, suffers,
# Nearest to is: was, are, became, has, finalised, were, makes, exists,
# Nearest to but: although, however, and, though, ticketing, than, centralised, untreated,
# Nearest to world: azariah, idriss, suspect, ethics, grams, bouts, pelham, spontaneity,
# Nearest to his: their, the, its, her, s, my, oakley, whose,
# Nearest to who: which, brahmagupta, already, troodos, howe, cj, priorities, eur,
# Nearest to and: or, but, while, although, unbeatable, asheville, harden, iain,
# Nearest to may: can, must, could, would, might, will, should, cannot,
# Average loss at step 22000: 4.400908
# Average loss at step 24000: 3.666281
# Average loss at step 26000: 3.587091
# Average loss at step 28000: 3.532909
# Average loss at step 30000: 3.562662
# Nearest to on: upon, within, under, in, hs, about, through, shale,
# Nearest to states: alexandria, theodosius, ahasuerus, diabelli, groups, mediterranean, peoples, boxer,
# Nearest to they: you, we, he, suspending, mpv, there, outbreaks, these,
# Nearest to as: fireside, rack, serine, coastline, lustrous, guilford, sandro, druidism,
# Nearest to this: it, which, the, what, another, that, secularism, pbk,
# Nearest to see: mai, blimp, mischievous, includes, normalization, dido, known, hein,
# Nearest to only: geneva, first, whether, failings, valdivia, supermarkets, fluent, attackers,
# Nearest to some: various, celtic, magnetism, diabelli, pacifica, yankovic, music, kaufman,
# Nearest to all: many, any, sines, every, some, other, both, cjd,
# Nearest to is: was, are, remains, has, became, contains, includes, were,
# Nearest to but: although, however, than, and, though, ethers, herbicides, zeppelins,
# Nearest to world: album, ethics, hoddle, cold, suspect, bouts, navel, idriss,
# Nearest to his: her, their, its, s, my, the, your, resolute,
# Nearest to who: diabelli, celtic, alexandria, theodosius, music, yankovic, boxer, virginia,
# Nearest to and: or, although, but, including, escorial, jama, unbeatable, loci,
# Nearest to may: can, could, must, would, will, should, might, cannot,
# Average loss at step 32000: 3.387374
# Average loss at step 34000: 3.457123
# Average loss at step 36000: 3.394507
# Average loss at step 38000: 3.420384
# Average loss at step 40000: 3.380280
# Nearest to on: upon, through, in, at, adic, pol, tanenbaum, within,
# Nearest to states: disagreement, alexandria, cycladic, job, community, theodosius, adjust, ahasuerus,
# Nearest to they: you, we, there, he, mae, epimenides, it, caveats,
# Nearest to as: restorations, pattern, before, suited, auction, dio, has, documentary,
# Nearest to this: which, it, the, another, she, that, what, he,
# Nearest to see: includes, called, mai, robbie, known, gaze, pretenders, requesting,
# Nearest to only: necessarily, currently, mundane, ung, actually, hardest, majority, term,
# Nearest to some: many, various, most, these, other, several, both, different,
# Nearest to all: several, particular, each, mainland, coordinates, disagreement, arose, samples,
# Nearest to is: was, remains, are, has, makes, became, includes, were,
# Nearest to but: however, while, than, and, rag, although, predates, see,
# Nearest to world: album, embroidered, hoddle, u, henning, bible, suspect, medians,
# Nearest to his: her, their, its, my, your, our, the, intrigued,
# Nearest to who: spongebob, living, mascots, howe, inasmuch, which, ofcom, painters,
# Nearest to and: or, while, including, but, casing, chariots, unbeatable, aleksei,
# Nearest to may: can, could, will, would, must, might, should, cannot,
# Average loss at step 42000: 3.396886
# Average loss at step 44000: 3.336498
# Average loss at step 46000: 3.284625
# Average loss at step 48000: 3.332819
# Average loss at step 50000: 3.185596
# Nearest to on: upon, in, under, around, masons, through, within, lindbergh,
# Nearest to states: nations, peers, negri, purcell, caballero, martins, tran, richardson,
# Nearest to they: you, forces, diabelli, we, armed, nancy, denmark, thirty,
# Nearest to as: cove, prepaid, auction, innocuous, restorations, mancala, galli, inherit,
# Nearest to this: which, another, what, a, that, praising, spink, leyte,
# Nearest to see: mai, locrian, discusses, references, starship, kraft, polyurethane, ellsworth,
# Nearest to only: materialism, always, marquesas, no, hunchback, vitrification, satie, still,
# Nearest to some: many, several, various, these, any, all, most, certain,
# Nearest to all: many, several, any, some, various, both, every, aerodynamically,
# Nearest to is: was, are, contains, has, remains, makes, were, becomes,
# Nearest to but: although, commonality, domains, though, promontory, cortez, and, shek,
# Nearest to world: club, country, gonna, hoddle, ethics, america, spontaneity, wily,
# Nearest to his: her, their, its, your, my, the, our, s,
# Nearest to who: he, pau, cj, which, lamont, enlarge, masefield, curries,
# Nearest to and: or, while, including, but, although, casing, barbarous, incoherent,
# Nearest to may: can, could, would, might, must, will, should, cannot,
# Average loss at step 52000: 3.246128
# Average loss at step 54000: 3.197802
# Average loss at step 56000: 3.052091
# Average loss at step 58000: 3.250212
# Average loss at step 60000: 3.191505
# Nearest to on: upon, through, under, about, around, in, onto, lindbergh,
# Nearest to states: nations, kingdom, terrain, peers, countries, provinces, ventricle, gridiron,
# Nearest to they: tisdall, space, diabelli, mysticism, monopolies, forces, armed, vector,
# Nearest to as: when, outdoors, selwyn, ojibwa, cousin, auction, how, stores,
# Nearest to this: which, it, what, intracranial, an, boomerangs, presupposition, amex,
# Nearest to see: mai, references, known, mischievous, dystopian, jacksonville, offensively, webmineral,
# Nearest to only: always, still, no, generally, recurring, until, also, auras,
# Nearest to some: many, various, several, all, most, numerous, conjectural, multiple,
# Nearest to all: many, some, several, various, both, lexus, any, every,
# Nearest to is: was, are, becomes, has, remains, became, makes, contains,
# Nearest to but: although, though, and, however, than, overtook, while, liga,
# Nearest to world: country, cold, hoddle, gonna, bible, club, eyes, bolshevist,
# Nearest to his: her, its, their, s, our, your, my, oakley,
# Nearest to who: he, pau, young, spongebob, brahmagupta, living, cumbria, that,
# Nearest to and: or, but, although, while, indentured, though, including, than,
# Nearest to may: can, might, could, must, will, would, should, cannot,
# Average loss at step 62000: 3.164448
# Average loss at step 64000: 3.042596
# Average loss at step 66000: 3.034162
# Average loss at step 68000: 4.140607
# Average loss at step 70000: 3.264252
# Nearest to on: upon, about, in, under, onto, through, around, iic,
# Nearest to states: nations, kingdom, vaccinium, terrain, uses, deified, resented, gridiron,
# Nearest to they: we, you, there, he, she, mpv, it, epimenides,
# Nearest to as: prepaid, downplayed, selwyn, like, imap, druidism, urals, embezzlement,
# Nearest to this: which, another, it, that, the, presupposition, a, what,
# Nearest to see: mai, provides, webmineral, jacksonville, polyurethane, include, fermilab, applies,
# Nearest to only: always, hardest, already, generally, linemen, until, paley, norsemen,
# Nearest to some: many, several, various, all, certain, these, numerous, both,
# Nearest to all: many, several, various, some, both, certain, numerous, berthe,
# Nearest to is: was, are, remains, makes, becomes, became, has, contains,
# Nearest to but: and, although, though, however, while, or, than, globin,
# Nearest to world: country, cold, sky, azariah, bible, northwestern, u, affective,
# Nearest to his: their, her, its, my, s, our, your, the,
# Nearest to who: young, he, sen, whose, pau, bryant, bing, meredith,
# Nearest to and: but, or, while, although, including, photoelectric, barbarous, switzer,
# Nearest to may: might, could, can, must, should, would, will, cannot,
# Average loss at step 72000: 3.175740
# Average loss at step 74000: 3.355879
# Average loss at step 76000: 3.101681
# Average loss at step 78000: 3.104623
# Average loss at step 80000: 2.938162
# Nearest to on: upon, in, about, onto, under, transcending, aggressively, behind,
# Nearest to states: kingdom, nations, engineers, disagreement, hawaii, laments, faculty, alexandria,
# Nearest to they: you, we, there, she, it, others, eudes, these,
# Nearest to as: untouchable, lustrous, fremantle, prepaid, auction, lollardy, innocuous, imap,
# Nearest to this: another, which, it, what, the, a, distinguishable, brute,
# Nearest to see: but, mai, supports, provides, includes, gave, jacksonville, called,
# Nearest to only: always, levellers, least, simply, identical, yet, currently, edi,
# Nearest to some: many, several, various, all, certain, both, multiple, none,
# Nearest to all: many, various, some, both, several, certain, any, none,
# Nearest to is: was, are, becomes, makes, remains, includes, exists, has,
# Nearest to but: though, however, although, and, see, because, or, which,
# Nearest to world: country, sky, europe, questionnaire, cold, azariah, bolshevist, vietnam,
# Nearest to his: her, their, its, your, my, our, the, s,
# Nearest to who: he, diabelli, tisdall, promontory, valentinian, yuan, croat, danish,
# Nearest to and: including, or, but, like, although, while, etc, though,
# Nearest to may: might, can, could, should, would, must, will, cannot,
# Average loss at step 82000: 3.005537
# Average loss at step 84000: 2.972196
# Average loss at step 86000: 2.970562
# Average loss at step 88000: 2.997489
# Average loss at step 90000: 2.934432
# Nearest to on: upon, in, onto, through, under, dragonball, sanjay, during,
# Nearest to states: nations, kingdom, provinces, deified, peers, alsace, vaccinium, gridiron,
# Nearest to they: we, you, there, he, she, ineffectiveness, it, epimenides,
# Nearest to as: lustrous, micheal, renn, fireside, auction, untouchable, downplayed, tapered,
# Nearest to this: it, another, which, what, a, arrayed, slowing, leyte,
# Nearest to see: supports, includes, gave, provides, contains, mai, include, applies,
# Nearest to only: always, hardest, currently, necessarily, exclusively, particularly, severely, billion,
# Nearest to some: many, several, various, certain, most, numerous, multiple, all,
# Nearest to all: various, many, both, numerous, some, every, identical, none,
# Nearest to is: was, remains, are, becomes, has, became, makes, includes,
# Nearest to but: though, however, although, and, while, etc, than, because,
# Nearest to world: country, europe, league, continent, poem, superhero, developments, field,
# Nearest to his: her, their, its, your, my, our, whose, the,
# Nearest to who: whom, sen, typically, always, deneb, which, young, disclosed,
# Nearest to and: or, while, etc, but, although, however, though, like,
# Nearest to may: can, might, must, should, will, could, would, cannot,
# Average loss at step 92000: 2.969640
# Average loss at step 94000: 2.950533
# Average loss at step 96000: 2.775823
# Average loss at step 98000: 2.511610
# Average loss at step 100000: 2.755458
# Nearest to on: upon, about, in, bloody, entitled, sanjay, onto, transcending,
# Nearest to states: nations, kingdom, state, gridiron, deified, peers, vaccinium, pectoral,
# Nearest to they: we, he, you, she, there, epimenides, baserunners, these,
# Nearest to as: lustrous, fireside, lollardy, commited, gaba, prepaid, restorations, pump,
# Nearest to this: which, another, it, presupposition, some, slumberland, lime, borda,
# Nearest to see: supports, include, consider, give, includes, mai, find, jacksonville,
# Nearest to only: always, every, best, identical, first, yet, enough, chopped,
# Nearest to some: many, several, various, all, numerous, most, certain, multiple,
# Nearest to all: many, various, numerous, some, every, identical, several, none,
# Nearest to is: was, are, exists, includes, makes, contains, remains, provides,
# Nearest to but: however, and, although, though, while, or, than, mishandling,
# Nearest to world: u, sky, cold, azariah, aftermath, gonna, poking, numismatic,
# Nearest to his: her, their, its, s, my, your, the, our,
# Nearest to who: whom, which, whose, tinctures, deneb, disclosed, phyllis, sen,
# Nearest to and: or, but, while, including, etc, though, whereas, mudslides,
# Nearest to may: might, can, would, should, could, must, will, shall,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
